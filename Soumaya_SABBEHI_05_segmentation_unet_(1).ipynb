# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------
# Copyright:
#
# Ce notebook a été conçu  et rédigé par Linda Marrakchi-Kacem pour l'atelier "Segmentation d'images médicales" qui s'inscrit dans le cadre du mastère TICV 2023-2024. Toute utilisation ou distribution de ce notebook en dehors du cadre de l'atelier doit porter la mention du nom de l'auteur.
#
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Chapitre 5 : Segmentation par classification supervisée (architecture UNet)

# %% [markdown]
# Ce notebook accompagne votre cinquième séance d'atelier. Il a pour objectif de vous montrer comment effectuer une segmentation en utilisant l'architecture UNet.

# %% [markdown]
# Deux options sont disponibles pour le téléchargement de la base de données:
#
# - Données 4D du site  http://medicaldecathlon.com/ (version difficile)
# - Données 2D simplifiée du contraste T1C téléchargeables à partir du lien suivant: https://www.dropbox.com/s/zmytk2yu284af6t/Task01_BrainTumour_2D.tar.gz (version facile)

# %% [markdown]
# ## Exercice 1: Implementation d'une classe pour le chargement et la division des données:

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.7.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2023.11.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# Mount data from drive
from google.colab import drive
drive.mount('/content/drive')

# Create Dataset4D directory
# !mkdir -p '/content/Dataset2D'

# Download the file
# !gdown --id 1-10tKKGmtN0eVAulDKZdc_FvUBKDLUff -O '/content/Dataset2D/Task01_BrainTumour_2D.tar'

# Extract the tar file
# !tar -xvf '/content/Dataset2D/Task01_BrainTumour_2D.tar' -C '/content/Dataset2D'
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Task01_BrainTumour_2D/training_labels/BRATS_076_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_095_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_055_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_282_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_225_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_429_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_086_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_128_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_278_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_065_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_032_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_460_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_357_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_166_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_155_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_061_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_319_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_238_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_130_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_264_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_169_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_146_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_448_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_421_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_469_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_316_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_091_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_223_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_069_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_196_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_131_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_255_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_382_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_043_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_425_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_461_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_436_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_284_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_199_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_440_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_294_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_341_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_119_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_304_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_372_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_476_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_444_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_170_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_234_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_376_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_357_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_438_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_002_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_251_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_313_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_159_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_227_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_272_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_270_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_421_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_386_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_437_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_165_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_470_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_132_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_051_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_359_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_292_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_388_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_348_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_208_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_015_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_042_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_176_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_431_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_191_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_306_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_338_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_030_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_172_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_011_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_046_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_179_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_055_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_161_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_176_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_019_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_204_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_038_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_466_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_272_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_199_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_189_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_384_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_402_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_284_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_223_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_411_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_282_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_469_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_323_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_169_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_121_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_355_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_442_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_480_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_213_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_059_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_327_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_262_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_370_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_334_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_428_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_012_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_257_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_200_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_160_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_346_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_311_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_272_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_244_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_038_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_474_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_423_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_402_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_146_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_282_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_355_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_093_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_377_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_059_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_213_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_480_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_232_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_440_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_265_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_078_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_107_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_334_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_342_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_315_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_295_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_075_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_470_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_070_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_252_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_027_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_359_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_051_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_417_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_387_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_320_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_478_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_150_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_100_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_157_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_022_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_085_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_418_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_176_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_388_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_213_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_172_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_030_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_456_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_338_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_104_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_319_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_153_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_055_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_269_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_063_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_329_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_083_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_255_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_404_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_156_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_453_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_425_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_382_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_381_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_440_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_411_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_246_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_211_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_159_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_254_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_372_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_444_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_368_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_065_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_395_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_188_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_376_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_234_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_242_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_008_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_159_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_313_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_251_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_450_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_365_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_178_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_386_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_421_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_400_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_095_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_032_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_408_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_057_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_076_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_134_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_180_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_140_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_407_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_408_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_397_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_086_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_429_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_170_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_242_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_073_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_155_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_101_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_174_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_369_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_123_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_130_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_238_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_219_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_371_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_448_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_399_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_193_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_478_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_042_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_197_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_130_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_044_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_106_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_065_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_278_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_032_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_340_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_021_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_163_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_329_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_308_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_142_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_198_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_232_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_295_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_095_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_146_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_025_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_003_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_091_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_171_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_469_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_301_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_436_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_197_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_061_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_348_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_273_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_040_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_054_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_417_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_284_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_359_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_461_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_436_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_267_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_325_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_482_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_181_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_304_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_119_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_202_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_340_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_461_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_356_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_223_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_069_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_224_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_297_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_129_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_227_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_270_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_015_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_318_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_293_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_476_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_420_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_357_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_265_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_168_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_321_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_263_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_188_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_388_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_285_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_222_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_063_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_121_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_229_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_015_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_208_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_042_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_006_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_144_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_165_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_132_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_093_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_161_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_248_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_263_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_140_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_002_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_311_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_097_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_438_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_161_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_191_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_011_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_046_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_429_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_125_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_067_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_397_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_234_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_293_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_430_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_411_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_148_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_240_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_323_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_169_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_346_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_225_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_204_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_191_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_019_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_044_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_349_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_384_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_199_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_257_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_200_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_221_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_129_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_178_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_430_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_307_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_451_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_442_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_434_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_393_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_005_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_327_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_370_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_308_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_306_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_244_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_416_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_430_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_397_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_386_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_321_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_240_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_148_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_225_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_346_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_311_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_474_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_423_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_342_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_315_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_129_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_221_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_212_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_470_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_295_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_451_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_062_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_458_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_393_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_434_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_232_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_078_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_265_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_480_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_244_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_110_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_306_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_337_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_390_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_400_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_478_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_148_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_229_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_121_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_063_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_245_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_100_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_157_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_144_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_006_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_338_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_070_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_027_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_092_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_035_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_093_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_147_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_376_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_269_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_002_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_441_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_140_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_248_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_204_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_438_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_097_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_379_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_319_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_104_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_106_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_153_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_067_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_125_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_417_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_094_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_033_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_409_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_482_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_325_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_267_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_246_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_399_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_211_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_340_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_243_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_202_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_297_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_331_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_404_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_453_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_178_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_365_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_100_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_400_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_448_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_476_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_293_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_188_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_395_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_202_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_447_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_242_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_008_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_263_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_321_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_370_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_157_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_193_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_408_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_106_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_044_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_025_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_170_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_329_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_163_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_021_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_158_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_255_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_057_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_327_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_180_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_410_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_219_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_116_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_025_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_369_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_399_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_119_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_197_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_214_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_369_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_174_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_123_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_366_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_451_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_040_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_348_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_393_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_334_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_469_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_403_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_039_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_448_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_219_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_246_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_130_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_174_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_091_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_040_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_144_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_197_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_249_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_044_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_375_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_442_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_170_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_032_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_278_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_078_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_193_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_207_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_408_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_077_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_180_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_329_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_134_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_105_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_163_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_208_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_057_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_400_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_385_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_386_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_270_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_250_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_178_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_251_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_087_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_020_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_357_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_376_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_321_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_188_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_152_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_444_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_454_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_372_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_325_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_119_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_211_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_211_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_440_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_417_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_284_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_461_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_061_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_382_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_404_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_202_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_255_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_154_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_097_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_438_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_140_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_081_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_026_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_319_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_011_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_153_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_030_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_067_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_324_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_383_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_229_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_063_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_157_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_015_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_218_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_388_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_067_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_093_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_365_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_359_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_144_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_132_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_070_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_068_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_142_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_257_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_315_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_030_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_097_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_221_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_232_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_370_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_240_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_078_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_306_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_405_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_442_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_098_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_434_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_395_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_148_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_355_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_103_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_282_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_430_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_201_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_423_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_384_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_272_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_444_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_038_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_225_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_019_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_311_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_057_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_451_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_228_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_315_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_257_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_125_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_334_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_129_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_078_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_370_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_462_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_232_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_213_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_244_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_059_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_355_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_442_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_227_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_393_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_240_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_269_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_397_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_164_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_019_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_402_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_423_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_384_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_314_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_423_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_266_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_311_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_019_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_133_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_055_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_248_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_002_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_153_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_011_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_319_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_343_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_125_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_338_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_474_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_172_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_231_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_121_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_176_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_015_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_157_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_172_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_388_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_435_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_051_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_006_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_270_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_070_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_132_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_290_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_400_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_421_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_476_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_293_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_178_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_270_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_345_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_313_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_159_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_357_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_238_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_263_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_234_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_192_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_188_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_047_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_482_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_267_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_211_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_119_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_009_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_433_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_461_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_284_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_304_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_279_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_297_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_425_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_404_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_174_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_340_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_006_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_469_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_221_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_219_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_025_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_238_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_464_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_174_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_123_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_155_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_348_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_289_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_051_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_106_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_278_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_032_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_260_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_170_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_429_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_086_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_408_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_482_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_425_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_180_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_021_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_076_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_057_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_010_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_040_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_251_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_369_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_123_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_061_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_197_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_089_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_323_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_384_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_448_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_153_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_091_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_399_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_086_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_021_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_130_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_146_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_095_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_210_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_142_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_308_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_134_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_329_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_163_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_362_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_065_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_044_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_060_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_193_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_376_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_321_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_247_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_242_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_008_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_392_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_335_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_444_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_395_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_402_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_038_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_145_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_386_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_248_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_251_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_090_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_365_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_227_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_453_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_382_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_069_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_223_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_443_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_202_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_255_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_079_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_246_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_104_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_304_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_209_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_372_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_325_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_436_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_440_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_417_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_076_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_030_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_067_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_031_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_096_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_104_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_046_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_191_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_404_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_438_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_097_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_394_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_140_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_241_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_269_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_161_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_070_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_093_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_027_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_165_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_144_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_359_z46.png
# Task01_BrainTumour_2D/training_labels/BRATS_042_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_100_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_445_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_208_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_372_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_229_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_063_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_200_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_478_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_306_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_327_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_265_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_027_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_480_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_434_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_155_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_258_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_325_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_382_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_470_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_412_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_028_z108.png
# Task01_BrainTumour_2D/training_labels/BRATS_295_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_221_z62.png
# Task01_BrainTumour_2D/training_labels/BRATS_342_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_257_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_200_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_199_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_474_z77.png
# Task01_BrainTumour_2D/training_labels/BRATS_066_z124.png
# Task01_BrainTumour_2D/training_labels/BRATS_204_z93.png
# Task01_BrainTumour_2D/training_labels/BRATS_114_z108.png
# ...
# Task01_BrainTumour_2D/test_labels/BRATS_220_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_465_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_288_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_137_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_050_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_261_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_071_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_112_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_358_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_424_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_389_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_014_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_463_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_333_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_401_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_275_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_017_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_118_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_139_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_373_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_016_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_195_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_175_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_037_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_475_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_052_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_449_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_230_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_468_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_135_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_173_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_303_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_024_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_398_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_332_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_071_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_064_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_126_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_373_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_143_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_309_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_259_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_477_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_029_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_413_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_256_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_115_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_452_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_360_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_296_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_217_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_452_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_322_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_088_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_415_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_190_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_479_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_194_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_363_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_120_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_113_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_109_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_471_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_414_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_326_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_481_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_036_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_396_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_322_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_205_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_347_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_475_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_109_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_220_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_353_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_286_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_471_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_414_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_481_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_326_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_184_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_312_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_149_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_303_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_322_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_347_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_205_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_162_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_475_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_472_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_048_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_141_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_237_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_439_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_190_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_135_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_194_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_479_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_276_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_299_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_194_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_041_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_296_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_203_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_360_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_452_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_302_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_182_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_398_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_280_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_041_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_058_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_045_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_126_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_064_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_016_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_162_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_328_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_309_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_143_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_484_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_344_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_457_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_432_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_029_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_276_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_300_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_391_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_099_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_135_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_472_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_048_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_361_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_237_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_472_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_004_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_162_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_312_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_102_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_184_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_127_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_353_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_286_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_363_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_108_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_484_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_415_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_016_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_280_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_261_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_058_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_484_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_182_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_367_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_291_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_455_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_023_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_302_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_419_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_299_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_195_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_459_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_296_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_194_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_299_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_041_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_023_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_452_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_217_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_419_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_299_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_115_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_195_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_029_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_413_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_256_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_259_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_373_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_108_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_071_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_415_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_332_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_484_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_261_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_302_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_291_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_167_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_004_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_127_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_036_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_206_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_113_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_457_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_413_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_432_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_300_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_363_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_099_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_391_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_361_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_048_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_088_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_415_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_322_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_280_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_465_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_215_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_332_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_261_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_424_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_317_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_274_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_336_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_288_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_050_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_220_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_230_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_465_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_353_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_082_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_175_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_036_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_111_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_053_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_072_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_432_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_184_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_115_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_288_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_236_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_291_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_151_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_344_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_303_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_173_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_427_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_088_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_380_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_406_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_330_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_475_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_253_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_230_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_446_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_195_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_217_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_236_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_374_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_084_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_017_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_136_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_074_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_182_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_463_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_378_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_186_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_080_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_084_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_074_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_136_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_117_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_102_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_113_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_378_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_099_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_333_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_080_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_143_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_034_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_463_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_286_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_351_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_276_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_380_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_088_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_427_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_253_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_467_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_446_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_374_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_236_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_080_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_036_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_017_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_112_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_053_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_111_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_455_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_184_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_115_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_288_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_414_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_013_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_259_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_465_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_280_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_215_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_332_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_374_z124.png
# Task01_BrainTumour_2D/test_labels/BRATS_206_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_037_z108.png
# Task01_BrainTumour_2D/test_labels/BRATS_336_z77.png
# Task01_BrainTumour_2D/test_labels/BRATS_274_z93.png
# Task01_BrainTumour_2D/test_labels/BRATS_138_z62.png
# Task01_BrainTumour_2D/test_labels/BRATS_353_z93.png

# %%
import os
import nibabel as nib
import numpy as np

# %%
# Définir le chemin des données
data_path = "/content/Dataset4D/Task01_BrainTumour/labelsTr"

# Lister les fichiers dans le répertoire
seg_samples = sorted(os.listdir(data_path))

# Remplacer le premier élément par 'BRATS_166.nii.gz'
seg_samples[0] = 'BRATS_166.nii.gz'

# Trier la liste
seg_samples = sorted(seg_samples)

# Initialiser les variables
saved_values = []
max_nb_values = 0

# Parcourir les échantillons
for sample in seg_samples:
    # Charger l'image NIfTI
    seg_img = nib.load(os.path.join(data_path, sample)).get_fdata()

    # Obtenir les valeurs uniques
    unique_values = np.unique(seg_img)
    nb_unique_values = len(unique_values)

    # Mettre à jour les valeurs maximales
    if nb_unique_values > max_nb_values:
        max_nb_values = nb_unique_values
        saved_values = unique_values

# Afficher le nombre maximal de valeurs dans toutes les images de segmentation
print(f"Maximum number of values in all segmentation images: {max_nb_values}")

# %%
# Specify path
data_path = "/content/Dataset4D/Task01_BrainTumour/imagesTr"

samples = os.listdir(data_path)
print("Number of samples:", len(samples))
VOLUME_START_AT = 60
VOLUME_SLICES = 75
samples_train, samples_val = train_test_split(samples, test_size=0.2, random_state=42)

samples_train, samples_test = train_test_split(samples_train, test_size=0.15, random_state=42)

# Print data distribution (Train , Test , Val)
print(f"Train length: {len(samples_train)}")
print(f"Validation length: {len(samples_val)}")
print(f"Test length: {len(samples_test)}")
# Out:
# Number of samples: 495
# Train length: 336
# Validation length: 99
# Test length: 60

# %%
from skimage.transform import rotate
from skimage.util import montage
import os
from sklearn.model_selection import train_test_split
import keras
import cv2
import tensorflow
import random
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from keras.callbacks import CSVLogger
import keras.backend as K
import zipfile
import pandas as pd

# %%
IMG_SIZE = 128
BATCH_SIZE = 1

# DataLoader
class DataLoader(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim= ( IMG_SIZE, IMG_SIZE), batch_size = BATCH_SIZE, n_channels = 2, shuffle=True):
        'Initialization'
        self.dim = tuple(dim) # Resized image dimensions (128 x 128)
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels # (T1CE + FLAIR)
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Load & Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples'
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES, 240, 240))

        # Generate data
        for c, i in enumerate(Batch_ids):

            # Get path of each RMI modality and the segmentation
            sample_path = os.path.join(data_path, i)
            seg_path = os.path.join('/content/Dataset4D/Task01_BrainTumour/labelsTr', i)
            ## print(sample_path)
            ## print(seg_path)

            #t1_path = sample_path + '_t1.nii'
            #t2_path = sample_path + '_t2.nii'

            # Extract the data from these paths
            modality = nib.load(sample_path).get_fdata()
            t1ce = modality[:, :, :, 2]
            flair = modality[:, :, :, 0]
            seg = nib.load(seg_path).get_fdata()
            #t1 = nib.load(t1_paths).get_fdata()
            #t2 = nib.load(t2_path).get_fdata()


            for j in range(VOLUME_SLICES):
                X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
                X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

                y[j + VOLUME_SLICES * c] = seg[:, :, j + VOLUME_START_AT]


        # Masks / Segmentations
        y[y==4] = 3
        mask = tensorflow.one_hot(y, 4)
        Y = tensorflow.image.resize(mask, (IMG_SIZE, IMG_SIZE))

        # Scale data between 0 and 1 (since the minimum value in the data is 0)
        return X/np.max(X), Y

training_generator = DataLoader(samples_train)
valid_generator = DataLoader(samples_val)
test_generator = DataLoader(samples_test)

# %% [markdown]
# ## Exercice 2: Implementation de l'architecture UNet

# %%
# U-Net
def build_unet(inputs, ker_init, dropout):
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)

    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    conv10 = Conv2D(4, 1, activation = 'softmax')(conv)

    return Model(inputs = inputs, outputs = conv10)

# %%
# Compute metric :
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss

def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
# Define input data shape
input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

# Build and compile the model
model = build_unet(input_layer, 'he_normal', 0.2)

model.compile(loss="categorical_crossentropy", optimizer=tensorflow.keras.optimizers.Adam(learning_rate=0.001), metrics = ['accuracy',tensorflow.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity] )

# %%
callbacks = [
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=2, min_lr=0.000001, verbose=1),

    keras.callbacks.ModelCheckpoint(filepath = 'model_.{epoch:02d}-{val_loss:.6f}.m5',
                             verbose=1, save_best_only=True, save_weights_only = True),

    CSVLogger('training.log', separator=',', append=False)
]

# %% [markdown]
# ## Exercice 3: Entrainement du UNet et test

# %%
model.fit(training_generator,
          epochs=10,
          steps_per_epoch=len(samples_train),
          callbacks=callbacks,
          validation_data=valid_generator)
# Out:
# Epoch 1/10
#   8/336 [..............................] - ETA: 2:35:28 - loss: 1.3938 - accuracy: 0.9724 - mean_io_u: 0.3757 - dice_coef: 0.2084 - precision: 0.8538 - sensitivity: 0.6900 - specificity: 0.9940

# %%
# Evaluate the model on the test data

results = model.evaluate(test_generator, batch_size=100, callbacks= callbacks)

descriptions = ["Loss", "Accuracy", "MeanIOU", "Dice coefficient", "Precision", "Sensitivity", "Specificity"]

results_list = zip(results, descriptions)

print("\nModel evaluation on the test set:")
print("==================================")
for i, (metric, description) in enumerate(results_list):
    print(f"{description} : {round(metric, 4)}")
